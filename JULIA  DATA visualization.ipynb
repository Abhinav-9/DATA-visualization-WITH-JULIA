# %%
import Pkg;    Pkg.add("DataFrames")
using DataFrames
# Out:
#    Updating registry at `C:\Users\sai rakshan\.julia\registries\General`
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`

# %%
import Pkg;    Pkg.add("CSV")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`

# %%
using CSV
x = CSV.read("C:\\Users\\sai rakshan\\Desktop\\rakshan.csv", DataFrame)
# Out:
# 569×32 DataFrame. Omitted printing of 27 columns
# │ Row │ id       │ diagnosis │ radius_mean │ texture_mean │ perimeter_mean │
# │     │ Int64    │ String    │ Float64     │ Float64      │ Float64        │
# ├─────┼──────────┼───────────┼─────────────┼──────────────┼────────────────┤
# │ 1   │ 842302   │ M         │ 17.99       │ 10.38        │ 122.8          │
# │ 2   │ 842517   │ M         │ 20.57       │ 17.77        │ 132.9          │
# │ 3   │ 84300903 │ M         │ 19.69       │ 21.25        │ 130.0          │
# │ 4   │ 84348301 │ M         │ 11.42       │ 20.38        │ 77.58          │
# │ 5   │ 84358402 │ M         │ 20.29       │ 14.34        │ 135.1          │
# │ 6   │ 843786   │ M         │ 12.45       │ 15.7         │ 82.57          │
# │ 7   │ 844359   │ M         │ 18.25       │ 19.98        │ 119.6          │
# │ 8   │ 84458202 │ M         │ 13.71       │ 20.83        │ 90.2           │
# │ 9   │ 844981   │ M         │ 13.0        │ 21.82        │ 87.5           │
# ...

# %%
head(x) #prints from top
# Out:
# 6×32 DataFrame. Omitted printing of 27 columns
# │ Row │ id       │ diagnosis │ radius_mean │ texture_mean │ perimeter_mean │
# │     │ Int64    │ String    │ Float64     │ Float64      │ Float64        │
# ├─────┼──────────┼───────────┼─────────────┼──────────────┼────────────────┤
# │ 1   │ 842302   │ M         │ 17.99       │ 10.38        │ 122.8          │
# │ 2   │ 842517   │ M         │ 20.57       │ 17.77        │ 132.9          │
# │ 3   │ 84300903 │ M         │ 19.69       │ 21.25        │ 130.0          │
# │ 4   │ 84348301 │ M         │ 11.42       │ 20.38        │ 77.58          │
# │ 5   │ 84358402 │ M         │ 20.29       │ 14.34        │ 135.1          │
# │ 6   │ 843786   │ M         │ 12.45       │ 15.7         │ 82.57          │

# %%
tail(x) #prints from bottom
# Out:
# 6×32 DataFrame. Omitted printing of 27 columns
# │ Row │ id     │ diagnosis │ radius_mean │ texture_mean │ perimeter_mean │
# │     │ Int64  │ String    │ Float64     │ Float64      │ Float64        │
# ├─────┼────────┼───────────┼─────────────┼──────────────┼────────────────┤
# │ 1   │ 926125 │ M         │ 20.92       │ 25.09        │ 143.0          │
# │ 2   │ 926424 │ M         │ 21.56       │ 22.39        │ 142.0          │
# │ 3   │ 926682 │ M         │ 20.13       │ 28.25        │ 131.2          │
# │ 4   │ 926954 │ M         │ 16.6        │ 28.08        │ 108.3          │
# │ 5   │ 927241 │ M         │ 20.6        │ 29.33        │ 140.1          │
# │ 6   │ 92751  │ B         │ 7.76        │ 24.54        │ 47.92          │

# %%
x[:, [:id, :diagnosis]] # it prints only id and diagnosis
# Out:
# 569×2 DataFrame
# │ Row │ id       │ diagnosis │
# │     │ Int64    │ String    │
# ├─────┼──────────┼───────────┤
# │ 1   │ 842302   │ M         │
# │ 2   │ 842517   │ M         │
# │ 3   │ 84300903 │ M         │
# │ 4   │ 84348301 │ M         │
# │ 5   │ 84358402 │ M         │
# │ 6   │ 843786   │ M         │
# │ 7   │ 844359   │ M         │
# │ 8   │ 84458202 │ M         │
# │ 9   │ 844981   │ M         │
# │ 10  │ 84501001 │ M         │
# ⋮
# │ 559 │ 925277   │ B         │
# │ 560 │ 925291   │ B         │
# │ 561 │ 925292   │ B         │
# │ 562 │ 925311   │ B         │
# │ 563 │ 925622   │ M         │
# │ 564 │ 926125   │ M         │
# │ 565 │ 926424   │ M         │
# │ 566 │ 926682   │ M         │
# │ 567 │ 926954   │ M         │
# │ 568 │ 927241   │ M         │
# │ 569 │ 92751    │ B         │

# %%
delete!(x,3) #it deletes the 3 coloumn
# Out:
# 568×32 DataFrame. Omitted printing of 27 columns
# │ Row │ id       │ diagnosis │ radius_mean │ texture_mean │ perimeter_mean │
# │     │ Int64    │ String    │ Float64     │ Float64      │ Float64        │
# ├─────┼──────────┼───────────┼─────────────┼──────────────┼────────────────┤
# │ 1   │ 842302   │ M         │ 17.99       │ 10.38        │ 122.8          │
# │ 2   │ 842517   │ M         │ 20.57       │ 17.77        │ 132.9          │
# │ 3   │ 84348301 │ M         │ 11.42       │ 20.38        │ 77.58          │
# │ 4   │ 84358402 │ M         │ 20.29       │ 14.34        │ 135.1          │
# │ 5   │ 843786   │ M         │ 12.45       │ 15.7         │ 82.57          │
# │ 6   │ 844359   │ M         │ 18.25       │ 19.98        │ 119.6          │
# │ 7   │ 84458202 │ M         │ 13.71       │ 20.83        │ 90.2           │
# │ 8   │ 844981   │ M         │ 13.0        │ 21.82        │ 87.5           │
# │ 9   │ 84501001 │ M         │ 12.46       │ 24.04        │ 83.97          │
# ...

# %%
select!(x, Not(:area_mean)) # it prints total x without "area_mean".
# Out:
# 568×31 DataFrame. Omitted printing of 26 columns
# │ Row │ id       │ diagnosis │ radius_mean │ texture_mean │ perimeter_mean │
# │     │ Int64    │ String    │ Float64     │ Float64      │ Float64        │
# ├─────┼──────────┼───────────┼─────────────┼──────────────┼────────────────┤
# │ 1   │ 842302   │ M         │ 17.99       │ 10.38        │ 122.8          │
# │ 2   │ 842517   │ M         │ 20.57       │ 17.77        │ 132.9          │
# │ 3   │ 84348301 │ M         │ 11.42       │ 20.38        │ 77.58          │
# │ 4   │ 84358402 │ M         │ 20.29       │ 14.34        │ 135.1          │
# │ 5   │ 843786   │ M         │ 12.45       │ 15.7         │ 82.57          │
# │ 6   │ 844359   │ M         │ 18.25       │ 19.98        │ 119.6          │
# │ 7   │ 84458202 │ M         │ 13.71       │ 20.83        │ 90.2           │
# │ 8   │ 844981   │ M         │ 13.0        │ 21.82        │ 87.5           │
# │ 9   │ 84501001 │ M         │ 12.46       │ 24.04        │ 83.97          │
# ...

# %%
replace!(x.radius_mean, (20.57) => (21.57)) #it replacing the value in the radius_mean
# Out:
# 568-element Array{Float64,1}:
#  17.99
#  21.57
#  11.42
#  20.29
#  12.45
#  18.25
#  13.71
#  13.0
#  12.46
#  16.02
#  15.78
#  19.17
#  15.85
#   ⋮
#   9.423
#  14.59
#  11.51
#  14.05
#  11.2
#  15.22
#  20.92
#  21.56
#  20.13
#  16.6
#  20.6
#   7.76

# %%
replace!(x.perimeter_mean, (132.9) => (142.2)) #it replacing the value in the perimeter_mean
# Out:
# 568-element Array{Float64,1}:
#  122.8
#  142.2
#   77.58
#  135.1
#   82.57
#  119.6
#   90.2
#   87.5
#   83.97
#  102.7
#  103.6
#  132.4
#  103.7
#    ⋮
#   59.26
#   96.39
#   74.52
#   91.38
#   70.67
#  103.4
#  143.0
#  142.0
#  131.2
#  108.3
#  140.1
#   47.92

# %%
x #print the updated x with new values
# Out:
# 568×31 DataFrame. Omitted printing of 26 columns
# │ Row │ id       │ diagnosis │ radius_mean │ texture_mean │ perimeter_mean │
# │     │ Int64    │ String    │ Float64     │ Float64      │ Float64        │
# ├─────┼──────────┼───────────┼─────────────┼──────────────┼────────────────┤
# │ 1   │ 842302   │ M         │ 17.99       │ 10.38        │ 122.8          │
# │ 2   │ 842517   │ M         │ 21.57       │ 17.77        │ 142.2          │
# │ 3   │ 84348301 │ M         │ 11.42       │ 20.38        │ 77.58          │
# │ 4   │ 84358402 │ M         │ 20.29       │ 14.34        │ 135.1          │
# │ 5   │ 843786   │ M         │ 12.45       │ 15.7         │ 82.57          │
# │ 6   │ 844359   │ M         │ 18.25       │ 19.98        │ 119.6          │
# │ 7   │ 84458202 │ M         │ 13.71       │ 20.83        │ 90.2           │
# │ 8   │ 844981   │ M         │ 13.0        │ 21.82        │ 87.5           │
# │ 9   │ 84501001 │ M         │ 12.46       │ 24.04        │ 83.97          │
# ...

# %%
#generation of random 50 rows and 2 columns of radius_mean and smoothness_mean
using Random         
Random.seed!(1);
df = DataFrame(rand(50,2), [:radius_meam, :smoothness_mean])
# Out:
# 50×2 DataFrame
# │ Row │ radius_meam │ smoothness_mean │
# │     │ Float64     │ Float64         │
# ├─────┼─────────────┼─────────────────┤
# │ 1   │ 0.236033    │ 0.440897        │
# │ 2   │ 0.346517    │ 0.404673        │
# │ 3   │ 0.312707    │ 0.736787        │
# │ 4   │ 0.00790928  │ 0.953803        │
# │ 5   │ 0.488613    │ 0.0951856       │
# │ 6   │ 0.210968    │ 0.519675        │
# │ 7   │ 0.951916    │ 0.0135403       │
# │ 8   │ 0.999905    │ 0.303399        │
# │ 9   │ 0.251662    │ 0.702557        │
# │ 10  │ 0.986666    │ 0.596537        │
# ⋮
# │ 40  │ 0.548983    │ 0.420287        │
# │ 41  │ 0.370971    │ 0.225151        │
# │ 42  │ 0.894166    │ 0.286169        │
# │ 43  │ 0.648054    │ 0.309144        │
# │ 44  │ 0.417039    │ 0.170391        │
# │ 45  │ 0.144566    │ 0.147162        │
# │ 46  │ 0.622403    │ 0.230063        │
# │ 47  │ 0.872334    │ 0.0929292       │
# │ 48  │ 0.524975    │ 0.681415        │
# │ 49  │ 0.241591    │ 0.762276        │
# ...

# %%
#generation of random data of 10 rows and 3 columns for radius_mean and smoothness_mean
using Random
Random.seed!(1);
df = DataFrame(rand(10, 3), [:perimeter_mean, :radius_mean, :smoothness_mean])
# Out:
# 10×3 DataFrame
# │ Row │ perimeter_mean │ radius_mean │ smoothness_mean │
# │     │ Float64        │ Float64     │ Float64         │
# ├─────┼────────────────┼─────────────┼─────────────────┤
# │ 1   │ 0.236033       │ 0.555751    │ 0.0769509       │
# │ 2   │ 0.346517       │ 0.437108    │ 0.640396        │
# │ 3   │ 0.312707       │ 0.424718    │ 0.873544        │
# │ 4   │ 0.00790928     │ 0.773223    │ 0.278582        │
# │ 5   │ 0.488613       │ 0.28119     │ 0.751313        │
# │ 6   │ 0.210968       │ 0.209472    │ 0.644883        │
# │ 7   │ 0.951916       │ 0.251379    │ 0.0778264       │
# │ 8   │ 0.999905       │ 0.0203749   │ 0.848185        │
# │ 9   │ 0.251662       │ 0.287702    │ 0.0856352       │
# │ 10  │ 0.986666       │ 0.859512    │ 0.553206        │

# %%
# breast cancer detection for above 16.5 of radius_mean
import Pkg; Pkg.add("DataFramesMeta")
using DataFramesMeta, DataFrames
@linq x |>
where(:radius_mean .> 16.5) |>
           select(number_of_people=:id)
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`
# 123×1 DataFrame
# │ Row │ number_of_people │
# │     │ Int64            │
# ├─────┼──────────────────┤
# │ 1   │ 842302           │
# │ 2   │ 842517           │
# │ 3   │ 84358402         │
# │ 4   │ 844359           │
# │ 5   │ 846226           │
# │ 6   │ 849014           │
# │ 7   │ 851509           │
# │ 8   │ 852552           │
# │ 9   │ 852631           │
# │ 10  │ 852781           │
# ⋮
# │ 113 │ 915143           │
# │ 114 │ 916799           │
# │ 115 │ 916838           │
# │ 116 │ 91762702         │
# │ 117 │ 91930402         │
# │ 118 │ 919555           │
# │ 119 │ 926125           │
# │ 120 │ 926424           │
# │ 121 │ 926682           │
# │ 122 │ 926954           │
# │ 123 │ 927241           │

# %%
Pkg.add("Plots")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`

# %%
import Pkg; Pkg.add("PyPlot")
using Plots
pyplot()
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`
# Plots.PyPlotBackend()

# %%
# ploting of histogram for radius_mean using plots
Plots.histogram(x[:radius_mean], xlabel = "Radius")

# %%
# ploting of histogram for texture_mean using plots
Plots.histogram(x[:texture_mean], xlabel = "texture")

# %%
# ploting of scatter for texture_mean using plots
Plots.scatter(x[:texture_mean] , title = "My Scatter Plot")

# %%
#ploting of both radius and texture_mean
plot(x.radius_mean, x.texture_mean)

# %%
p1 = plot(x.radius_mean, x.texture_mean , )
p2 = Plots.scatter(x[:texture_mean] , title = "My Scatter Plot")

p3 = Plots.histogram(x[:radius_mean], xlabel = "Radius")
p4 = Plots.histogram(x[:texture_mean], xlabel = "texture")
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %%
import Pkg; Pkg.add("StatsPlots")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`

# %%
import Pkg; Pkg.add("Interact")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`

# %%
import Pkg; Pkg.add("Blink")
# Out:
#   Resolving package versions...
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\sai rakshan\.julia\environments\v1.5\Manifest.toml`

# %%
#CREATION OF GUI(GRAPHICAL_USER_INTERFACE) FOR THE "X"
using StatsPlots, Interact
using Blink

w = Window()
body!(w, dataviewer(x))
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-8466488952359260675\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-17553599961994335363\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...

# %%
# creation of marginalhist of radius mean and texture mean
@df x marginalhist(:radius_mean, :texture_mean)

# %%
# creation of marginalhist of perimeter and smoothness mean
@df x marginalhist(:perimeter_mean, :smoothness_mean)

# %%
#CREATION OF SCATTERHIST FOR PERIMETER AND SMOOTHNESS_MEAN
@df x scatterhist(:perimeter_mean, :smoothness_mean)

# %%
println("THANK YOU")
# Out:
# THANK YOU😊
# MethodError: no method matching isnan(::String)
# Closest candidates are:
#   isnan(::BigFloat) at mpfr.jl:881
#   isnan(::Missing) at missing.jl:100
#   isnan(::Float16) at float.jl:537
#   ...
# Stacktrace:
#  [1] _quantilesort!(::PooledArrays.PooledArray{String,UInt32,1,Array{UInt32,1}}, ::Bool, ::Float64, ::Float64) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Statistics\src\Statistics.jl:960
#  [2] #quantile!#49 at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Statistics\src\Statistics.jl:938 [inlined]
#  [3] quantile(::PooledArrays.PooledArray{String,UInt32,1,Array{UInt32,1}}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}; sorted::Bool, alpha::Float64, beta::Float64) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Statistics\src\Statistics.jl:1052
# ...
